# %% [markdown]
# # Political Bias Detection in German News Articles

# %%
from explore_data import*
from prepare_data import*
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### GermaParl

# %%
germa_parl = GermaParl('GermaParlTEI')

# %%
germa_parl.number_of_samples
# Out:
# 254405

# %%
num_samples_per_class(germa_parl.labels)

# %%
num_words_per_sample(germa_parl.texts)
# Out:
# 75.0

# %%
plot_sample_length_distribution(germa_parl.texts)

# %%
gp_word_frequency = plot_word_frequency_distribution(germa_parl.texts)

# %% [markdown]
# ### News Articles

# %% [markdown]
# #### Junge Freiheit

# %%
jf = LoadArchive('jungefreiheit_archive.pkl')

# %%
jf.number_of_samples
# Out:
# 75410

# %%
num_words_per_sample(jf.texts)
# Out:
# 464.0

# %%
plot_sample_length_distribution(jf.texts)

# %%
jf_word_frequency = plot_word_frequency_distribution(jf.texts)

# %% [markdown]
# #### Jungle World

# %%
jw = LoadArchive('jungleworld_archive.pkl')

# %%
jw.number_of_samples
# Out:
# 45227

# %%
num_words_per_sample(jw.texts)
# Out:
# 771.0

# %%
plot_sample_length_distribution(jw.texts)

# %%
jw_word_frequency = plot_word_frequency_distribution(jw.texts)

# %% [markdown]
# #### Sueddeutsche Zeitung

# %%
sz = LoadArchive('sueddeutsche_archive.pkl')

# %%
sz.number_of_samples
# Out:
# 69507

# %%
num_words_per_sample(sz.texts)
# Out:
# 327.0

# %%
plot_sample_length_distribution(sz.texts)

# %%
sz_word_frequency = plot_word_frequency_distribution(sz.texts)

# %% [markdown]
# ### Bringing everything together

# %%
data = germa_parl.texts + jf.texts + jw.texts + sz.texts
labels = germa_parl.labels + jf.labels + jw.labels + sz.labels

# %%
len(data)
# Out:
# 444549

# %%
num_words_per_sample(data)
# Out:
# 266.0

# %%
plot_sample_length_distribution(data)

# %%
data_word_frequency = plot_word_frequency_distribution(data)

# %%
num_samples_per_class(labels)

# %% [markdown]
# ## Data Preperation and Model Building

# %% [markdown]
# Calculate the number of samples/number of words per sample ratio.

# %%
len(data)/num_words_per_sample(data)
# Out:
# 1671.2368421052631

# %% [markdown]
# Ratio is greater than 1500, we tokenize the text as sequences and use a pretrained fine-tuned pre-trained embedding.

# %%
vect_texts, word_index = sequence_vectorize(data)

# %%
train_texts, train_labels, val_texts, val_labels, test_texts, test_labels = train_val_test_split(vect_texts, labels)
# Out:
# /opt/anaconda/envs/PoliticalBiasDetection/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
